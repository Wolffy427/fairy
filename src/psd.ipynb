# %%
from psd_tools import PSDImage

psd = PSDImage.open('../data/psd/武将觐见617.psd')
psd
# Out:
# PSDImage(mode=3 size=1600x720 depth=8 channels=3)
#   [0] PixelLayer('背景' size=1600x720)
#   [1] Group('bg' size=2790x1040)
#     [0] PixelLayer('图层 1' size=1920x1040)
#     [1] PixelLayer('图层 2' size=1920x1040 invisible)
#     [2] PixelLayer('图层 3' size=1920x1040)
#     [3] SmartObjectLayer('图层 4' size=2016x1040)
#     [4] PixelLayer('图层 5' size=1920x1040 mask)
#     [5] Group('组 6018' mask)
#       [0] SmartObjectLayer('图层 6' size=1920x1040 invisible)
#       [1] PixelLayer('图层 7' size=1560x720 invisible)
#     [6] PixelLayer('图层 8' size=1609x620 effects)
#     [7] PixelLayer('图层 9' size=1200x900 mask)
#     [8] PixelLayer('レイヤー 13' size=1741x900 mask)
#     [9] SmartObjectLayer('图层 10' size=1623x826 mask)
#     [10] PixelLayer('图层 11' size=904x720 effects)
#     [11] PixelLayer('图层 12' size=1920x177 mask)
#   [2] PixelLayer('组 6041（合并）' size=2790x1040 invisible)
#   [3] Group('3人立绘 75%' invisible)
#     [0] Group('马忠' mask)
#       [0] SmartObjectLayer('m_mazhong' size=307x438)
# ...

# %%
psd[15].composite()
# Out:
# <PIL.Image.Image image mode=RGBA size=84x114>
